# %% [markdown]
# # Strings in Python

# %% [markdown]
# In python there is no character data type, a character is a string of length one. It is represented by str class

# %% [markdown]
# ## Built-in functions

# %% [markdown]
# A method is like a function, it runs on an object and returns the result.
#
# > The original object is not altered because of these methods.
#
# 1. "+" operator:
#   1. it is used to concatenate strings.
#   2. It does not automatically converts the number or other data types to string form.
#   3. You have to use the str() function for the conversion.
#
# 2. "*" operator: to repeat the string required number of times.
# 3. <font color  = "purple"><b>Len()</b></font>: return the length of the string
# 4. <font color  = "purple"><b>Str.capitalize()</b></font>: Returns the copy of the string with its first character capitalized and rest in lower case.
# 5. <font color  = "purple"><b>Str.title()</b></font>: Returned the titled case version of the string. For this the algorithm uses a simple language independent definition of the word as a group of consecutive letters. This means, apostrophes also form the Word boundaries.
# 6. <font color  = "purple"><b>Str.upper()</b></font>: will return all the characters as upper case
# 7. <font color  = "purple"><b>Str.lower()</b></font>: will return all the characters as lower case
# 8. <font color  = "purple"><b>Str.swapcase()</b></font>: Uppercase letters are converted to lowercase and vice versa.
# 9. <font color  = "purple"><b>Str.islower()</b></font>, <font color  = "purple"><b>str.isupper()</b></font>, <font color  = "purple"><b>str.isspace()</b></font>, <font color  = "purple"><b>str.istitle()</b></font>  - Returns True or False based on the presences of type of case in the string.
# 10. <font color  = "purple"><b>str.find(substring)</b></font>: Gives the position of any character or of a subString within any given string and returns the index of the location. If the sub-string is not found in the string, returns "-1".
# 10. <font color  = "purple"><b>Str.count(sub, start, end)</b></font>: Returns the number of non-overlapping occurrences of the sub string in the range [start, end]. The optional start and end as considered as slice notation
# 11. <font color  = "purple"><b>Str.startswith(sub, start, end)</b></font>,
# <font color  = "purple"><b>str.endswith(sub, start, end)</b></font>: Test if the string starts/ ends with the given sub.
# 12. <font color  = "purple"><b>String.replace('New', 'Old', count)</b></font>: replaces a part of the string with the new string. This is case sentitive.
# 13. <font color  = "purple"><b>String.split(separator)</b></font>: allows you to create a list of string based on the separator and returns a list of all separated elements. By default its a white space

# %%
mystring = "This is not my first String"
print(mystring)
# Out:
# This is not my first String

# %%
# Accessing individual characters from the string
print(mystring[0])
# Out:
# T

# %%
# Concatenation 
print("Hello" + " World")
print("Hello " * 3)
# Out:
# Hello World
# Hello Hello Hello

# %%
# Check existence of a character or a sub-string in a string
"not" in mystring
# Out:
# True

# %%
# Returning the length of the string
len(mystring)
# Out:
# 27

# %%
# Running various captialisation functions on the string
print("All Cap: " ,mystring.upper())
print("All Lower: ", mystring.lower())
print("Capitalised: ",mystring.capitalize())
print("Title Case: ", mystring.title())
# Out:
# All Cap:  THIS IS NOT MY FIRST STRING
# All Lower:  this is not my first string
# Capitalised:  This is not my first string
# Title Case:  This Is Not My First String

# %%
# sub-string found in the main string, returns the index
print(mystring.find("first"))

#sub-string not found, returns -1
print(mystring.find("done"))
# Out:
# 15
# -1

# %% [markdown]
# 1. <font color  = "purple"><b>rfind()</b></font> method returns the rightmost index of the substring if found in the given string. If not found then it returns -1.If we pass the start and end parameters to the Python String rfind() Method, it will search for the substring in the portion of the String from its right side.
# 2. The <font color  = "purple"><b>index()</b></font> method is similar to find(). The only difference is find() returns -1 if the searched string is not found and index() throws an exception in this case

# %%
# Replacing the sub-stirng 
mystring.replace("String", "code")
# Out:
# 'This is not my first code'

# %%
mystring.split()
# Out:
# ['This', 'is', 'not', 'my', 'first', 'String']

# %% [markdown]
# <font color  = "purple"><b>partition()</font></b> method splits the string at the first occurrence of the separator and returns a <b>tuple</b> containing the part before the separator, separator and the part after the separator. Python String partition() Method returns the original string as the first element of the tuple, and the remaining two elements are empty.

# %% [markdown]
# **Other useful String methods**
#
# 1. <font color  = "purple"><b>str.center(length, filler)</font></b>:
#   1. Method tries to keep the new string length equal to the given length value and fills the extra characters using the default character (space in this case).
#   2. Returns a string padded with specified fillchar and it doesn’t modify the original string.
#   3. center() Method with length argument value less than original String length
#
# 2. <font color  = "purple"><b>separator.join(string)</b></font>:
#   1. Basic use to convert any iterable object into a string
#   2. It is an inbuilt string function in Python used to join elements of the sequence separated by a string separator. This function joins elements of a sequence and makes it a string.
#   2. If the iterable contains any non-string values, it raises a TypeError exception.
#   3. It can be used to join strings with other strings, tuple, list, sets and dictionay. When joining a string with a dictionary, it will join with the keys of a Python dictionary, not with values.
#
# 3. <font color  = "purple"><b>strip(characters):</font></b>
#   1. other variations: rstrip/lstrip
#   2. method returns a copy of the string with leading characters removed (based on the string argument passed). If no argument is passed, it removes leading spaces.
#   3. It removes leading and trailing characters that are present in the argument, but not those characters in the middle of the string.
#
# 4. <font color  = "purple"><b>String zfill():</font></b> method returns a copy of the string with ‘0’ characters padded to the left side of the given string.

# %%
# Using the join functions to combine all the elements of the list into a string. 
print("orginal elements:" ,mystring.split())
newstring = "-".join(mystring.split())
print("using Join new string: ", newstring)
# Out:
# orginal string: ['This', 'is', 'not', 'my', 'first', 'String']
# using Join new string:  This-is-not-my-first-String

# %%
# Center method
string = "Done"
print(string)
print(string.center(10))
print(string.center(10, "-"))
# Out:
# Done
#    Done
# ---Done---

# %%
# Understanding the strip method - just the white spaces

string = "  never @@ give up -- on # any thing $. "
print("Original string:",string, len(string))
print("Stripped string:",string.strip(), len(string.strip()))
print("Right stripped string:",string.rstrip(), len(string.rstrip()))
print("left stripped string:",string.lstrip(), len(string.lstrip()))
# Out:
# Original string:   never @@ give up -- on # any thing $.  40
# Stripped string: never @@ give up -- on # any thing $. 37
# Right stripped string:   never @@ give up -- on # any thing $. 39
# left stripped string: never @@ give up -- on # any thing $.  38

# %%
print(string.strip(" ne"))
# Out:
# ver @@ give up -- on # any thing $.

# %% [markdown]
# To strip the charaters from anywhere within the string we would use following function
#
# <font color  = "purple"><b>Translate()</font></b>: Will change the string by replacing the characters or by deleting them.
# 1. it does the individual character level replacement.
# 2. the functions does that based on the translation table. which can be created using the <font color  = "purple"><b>maketrans()</b></font> method.
#
# <font color  = "purple"><b>str.maketrans(x, [y, z])</font></b>: string method that returns a translation table.
# 1. X is the compulsary argument while y and z are optional
# 2. when we pass only one argument it has to be a replacement dictionary
# 3. when we pass two arguments, they must be string of equal length. Each character in  X will be mapped to the character at the same index in Y.
# 4. If there is a third argument, then it should be string, whose character will be mapped to none in the result.

# %%
# Removing the all the special characters in a single statement. 
print("orinigal string:" ,string)
transtable = string.maketrans(" "," ", "@-#$")
newstring = string.translate(transtable)
print("new string: ", newstring)

#we can work on the new string to bring it to better shape by removing the extra spaces
newstring = " ".join(newstring.split())
newstring
# Out:
# orinigal string:   never @@ give up -- on # any thing $.
# new string:    never  give up  on  any thing .
# 'never give up on any thing .'

# %% [markdown]
# Two or more string literals next to each other are automatically concatenated. This feature is important when you want to break long string. This works with the string literals, but not with the variables & expressions.

# %%
print("Hello" "world")
# Out:
# Helloworld

# %% [markdown]
# ## String formating with print

# %% [markdown]
# So there are multiple ways to format strings for printing the variables in them. This is known as string interpolation.
# There are two methods to format strings:
# .format()
# F-strings [formatted string literals]
# .format()
# With this methods, you are going to have your strings defined, with the curly braces as the place holder for the variable.
# The strings in the place holder are inserted in the indexed manner.
# The format functions supply the input in the same manner, as in the argument.
# You can either provide the index in the curly braces, or you can have key value pair in the format function [keyword assignment like the variable assignment] and pass the key in the curly braces.
# You can also use the variable defined outside the format statement.
# Formatting Float:

# %% [markdown]
# # List in Python

# %% [markdown]
# ## Basic Operations on list

# %% [markdown]
# List concatenations: You can use the add (+)  operator to concatenate two list  together. It basically appends the second list to the list one.
# S.extend(t): Extend the list S with content of list T.
# List replication: You can use the multiply (*) operator to replicate the items in the list. You have to multiply a list with an integer for the replication.
# List * n : if the value of n is less than 0, it is treated as zero, which yields an empty list.
# The items in the list are not copied, they are referenced multiple times. ( so any change made to one is reflected in the final list).
# If its a list of list, modifying any element of the list, modifies the result list.
# Comparison Operator: you can pass a comparison operator between two list.
# The operator do an element by element comparison between the lists.
# The first items of both the list are compared, if they differ, this determine the outcome of the comparison.
# If all the items of the list (or sequence in general) compares equal, the sequence are considered equal.
# If one sequence is an initial sub-sequence of the other, the shorter sequence is the smaller (lesser) one.
# The exceptions are not suppressed, if any comparison fails, the entire operation will fail.
# Presence of an Element: to check whether or not an element is in list we use the IN/ Not IN operator.
# It returns True or False depending on the presence.
# In/Not In have the same priority as the comparison operator.

# %% [markdown]
# ## Built-in functions

# %% [markdown]
# List. Index( X , <start index>, <stop index>):
# Returns the index of the position of the first occurrence of X
# If there are duplicates, it reports the first occurrence only.
# Raises a Value Error if X is not present.
# Append():
# Add the element at the end of the list
# The list is modified in place.
# Insert (Index, Value):
# Add the element at the specified location
# Remove (Value):
# Removes the value from the list - irrespective of its location.
# If there are multiple values, the first instance get removed
# Pop (I):
# Removes the element at index i
# If I is not defined, it removes the last element from the list.
# It is also possible to use list as a queue.
# The first in and fist out using the popleft() function - which removes the left most element from the list.
# To use this feature, use collection.deque  which allows popping from both the ends of the list.
# Del list [<index>]:
# This function is used to delete the element from the list at the defined index.
# Deletes the memory associated with the list.
# Clear():
# Clear all the content of the list.
# Copy():
# Creates the copy of the list.
# The copy remain, also if the original list has been deleted. This is called as Deep Copy
# You can create the shallow copy by using the assignment operator. They refer of the same list in the memory (passes the reference of the object). The changes made in the one will be reflected in the other as well. This holds true even in the local scope.
# However if you use the list() function to assign a list, it creates a new list in the memory.
# Sort( reverse = T/F, key = str.lower):
# Sort the list in the ascending direction by default.
# If there are both numeric and string data types in the list, python does not know how to sort and throws an error.
# Key takes any function as it value (ex str.lower) . This function transform each element before sorting. This can also take the user defined functions.
# Modifies the list in place.
# Sorted(list_name) is also an inbuilt function, and return the sorted list as an output and it does not modify the original list.
# Reverse ():
# Reverse the order of the elements in the list.
# Modifies the sequence in place for economy of space.
# Count (X):
# Returns the number of time x appeared in the list.

# %% [markdown]
# ## List Comprehension

# %% [markdown]
# List comprehension provides a concise way to create list.
# Application are to make a new list, where each element is a result of some operation applied to each member of another sequence/ iterables or to create a sub sequence where certain conditions are met.
# Structure: Square brackets containing expression followed by for clause, then zero or more for/if clause.
# Its a kind of a FOR LOOP, but in backward direction.
# [ X for … ]  X is something that you want to append to the new list.
